# %%
import numpy as np

red_data = np.loadtxt('.\HW1\winequality-red.csv', delimiter=';', skiprows=1)
white_data = np.loadtxt('.\HW1\winequality-white.csv', delimiter=';', skiprows=1)

# %%
red_data
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
Red_data = np.concatenate((red_data[:,:-1], np.ones((red_data.shape[0], 1))), axis=1)
Red_data
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  1.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  1.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  1.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  1.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  1.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  1.   ]])

# %%
Red_data[-100:,:]
# Out:
# array([[ 6.9  ,  0.74 ,  0.03 , ...,  0.63 , 11.5  ,  1.   ],
#        [ 7.5  ,  0.725,  0.04 , ...,  0.53 ,  9.6  ,  1.   ],
#        [ 7.8  ,  0.82 ,  0.29 , ...,  0.53 ,  9.4  ,  1.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  1.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  1.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  1.   ]])

# %%
white_data
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  0.45,  8.8 ,  6.  ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  0.49,  9.5 ,  6.  ],
#        [ 8.1 ,  0.28,  0.4 , ...,  0.44, 10.1 ,  6.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]])

# %%
red_x_data = red_data[:, :11]
red_y_data = red_data[:, -1, np.newaxis]
red_X_data = np.concatenate((red_x_data, np.ones((1599, 1))), axis=1)
xmat = np.mat(red_X_data)
ymat = np.mat(red_y_data)
xmat
# Out:
# matrix([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  1.   ],
#         [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  1.   ],
#         [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  1.   ],
#         ...,
#         [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  1.   ],
#         [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  1.   ],
#         [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  1.   ]])

# %%
xmat.shape
# Out:
# (1599, 11)

# %%
ymat
# Out:
# matrix([[5.],
#         [5.],
#         [5.],
#         ...,
#         [6.],
#         [5.],
#         [6.]])

# %%
ymat.shape
# Out:
# (1599, 1)

# %%
red_train_data = red_data[:-100, :10]
red_train_data
# Out:
# array([[7.4    , 0.7    , 0.     , ..., 0.9978 , 3.51   , 0.56   ],
#        [7.8    , 0.88   , 0.     , ..., 0.9968 , 3.2    , 0.68   ],
#        [7.8    , 0.76   , 0.04   , ..., 0.997  , 3.26   , 0.65   ],
#        ...,
#        [7.7    , 0.54   , 0.26   , ..., 0.99636, 3.26   , 0.59   ],
#        [6.9    , 0.74   , 0.03   , ..., 0.99508, 3.45   , 0.63   ],
#        [6.6    , 0.895  , 0.04   , ..., 0.99582, 3.53   , 0.58   ]])

# %%
red_train_data.shape[0]
# Out:
# 1499

# %%
red_test_data = red_data[-100:, :10]
red_test_data
# Out:
# array([[6.9000e+00, 7.4000e-01, 3.0000e-02, 2.3000e+00, 5.4000e-02,
#         7.0000e+00, 1.6000e+01, 9.9508e-01, 3.4500e+00, 6.3000e-01],
#        [7.5000e+00, 7.2500e-01, 4.0000e-02, 1.5000e+00, 7.6000e-02,
#         8.0000e+00, 1.5000e+01, 9.9508e-01, 3.2600e+00, 5.3000e-01],
#        [7.8000e+00, 8.2000e-01, 2.9000e-01, 4.3000e+00, 8.3000e-02,
#         2.1000e+01, 6.4000e+01, 9.9642e-01, 3.1600e+00, 5.3000e-01],
#        [7.3000e+00, 5.8500e-01, 1.8000e-01, 2.4000e+00, 7.8000e-02,
#         1.5000e+01, 6.0000e+01, 9.9638e-01, 3.3100e+00, 5.4000e-01],
#        [6.2000e+00, 4.4000e-01, 3.9000e-01, 2.5000e+00, 7.7000e-02,
#         6.0000e+00, 1.4000e+01, 9.9555e-01, 3.5100e+00, 6.9000e-01],
#        [7.5000e+00, 3.8000e-01, 5.7000e-01, 2.3000e+00, 1.0600e-01,
#         5.0000e+00, 1.2000e+01, 9.9605e-01, 3.3600e+00, 5.5000e-01],
#        [6.7000e+00, 7.6000e-01, 2.0000e-02, 1.8000e+00, 7.8000e-02,
#         6.0000e+00, 1.2000e+01, 9.9600e-01, 3.5500e+00, 6.3000e-01],
# ...
